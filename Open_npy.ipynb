# %%
import numpy as np

# %%
data = np.load(r'C:\Users\Louis\PycharmProjects\HTS-Audio-Transformer\anomaly_detection_workspace\Data\data.npy',allow_pickle=True) 
print(data)
# Out:
# [list([{'name': '2025-03-19_Test_coupon_2.wav', 'target': 1, 'waveform': array([6.1035156e-05, 1.5258789e-04, 2.7465820e-04, ..., 5.4992676e-02,
#         5.4992676e-02, 5.4962158e-02], dtype=float32)}, {'name': 'Cross_s1_p1cycle_086.wav', 'target': 1, 'waveform': array([0.00048828, 0.00057983, 0.00067139, ..., 0.01992798, 0.01992798,
#         0.01989746], dtype=float32)}, {'name': 'Cross_s1_p3cycle_181.wav', 'target': 1, 'waveform': array([0.00131226, 0.00149536, 0.00167847, ..., 0.0171814 , 0.01715088,
#         0.01712036], dtype=float32)}, {'name': 'Cross_s1_p3cycle_356.wav', 'target': 1, 'waveform': array([0.00097656, 0.00106812, 0.00115967, ..., 0.02450562, 0.02459717,
#         0.02468872], dtype=float32)}, {'name': 'cross_p7s1_cycle_593.wav', 'target': 1, 'waveform': array([0.00238037, 0.00262451, 0.00286865, ..., 0.02316284, 0.02310181,
# ...
