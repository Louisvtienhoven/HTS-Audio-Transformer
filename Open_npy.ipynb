# %%
import numpy as np

# %%
data = np.load(r'C:\Users\Louis\PycharmProjects\HTS-Audio-Transformer\workspace\esc-50\esc-50-data.npy',allow_pickle=True) 
print(data)
# Out:
# [list([{'name': 'cross_p7s1_cycle_004.wav', 'target': 0, 'waveform': array([0.00234985, 0.00247192, 0.00262451, ..., 0.00259399, 0.00234985,
#         0.00213623], dtype=float32)}, {'name': 'cross_p7s1_cycle_014.wav', 'target': 0, 'waveform': array([-0.00408936, -0.00418091, -0.00427246, ...,  0.00091553,
#          0.00073242,  0.00064087], dtype=float32)}, {'name': 'cross_p7s1_cycle_024.wav', 'target': 0, 'waveform': array([3.0517578e-05, 1.2207031e-04, 1.5258789e-04, ..., 7.3242188e-04,
#         6.1035156e-04, 5.1879883e-04], dtype=float32)}, {'name': 'cross_p7s1_cycle_034.wav', 'target': 0, 'waveform': array([0.00195312, 0.00216675, 0.00234985, ..., 0.00152588, 0.00137329,
#         0.00125122], dtype=float32)}, {'name': 'cross_p7s1_cycle_044.wav', 'target': 0, 'waveform': array([0.00378418, 0.00402832, 0.00430298, ..., 0.00408936, 0.00357056,
# ...
