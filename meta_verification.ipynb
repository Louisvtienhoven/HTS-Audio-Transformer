# %%
import pandas as pd
import os

# Define paths
meta_csv_path = r"C:\Users\Louis\PycharmProjects\HTS-Audio-Transformer\anomaly_detection_workspace\Data\raw\Master\meta\meta_final_dataset.csv"
audio_dir = r"C:\Users\Louis\PycharmProjects\HTS-Audio-Transformer\anomaly_detection_workspace\Data\raw\Master\Dataset_final_train_ver"
output_meta_path = r"C:\Users\Louis\PycharmProjects\HTS-Audio-Transformer\anomaly_detection_workspace\Data\raw\Master\meta\meta_train_ver.csv"

# Load metadata CSV
meta_df = pd.read_csv(meta_csv_path)

# Get list of audio files in the train/verification folder
available_files = set(os.listdir(audio_dir))

# Filter the DataFrame to only include rows with filenames that exist in the folder
filtered_meta_df = meta_df[meta_df['filename'].isin(available_files)]

# Save the filtered DataFrame to a new CSV
filtered_meta_df.to_csv(output_meta_path, index=False)

print(f"Filtered metadata saved to {output_meta_path}")
# Out:
# Filtered metadata saved to C:\Users\Louis\PycharmProjects\HTS-Audio-Transformer\anomaly_detection_workspace\Data\raw\Master\meta\meta_train_ver.csv
